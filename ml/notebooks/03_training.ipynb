# %% [markdown]
# # AlgoRhythm — Training
#
# XGBoost + Optuna + SHAP. The script version is `src/train.py`.

# %%
import sys; sys.path.append('../src')
# Train end-to-end (writes artifacts/):
import train
# Or from the shell: python src/train.py --trials 60

# %% [markdown]
# ## Global SHAP summary
# After training, see `artifacts/shap_summary.png`.
