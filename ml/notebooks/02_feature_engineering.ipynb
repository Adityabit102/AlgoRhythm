# %% [markdown]
# # AlgoRhythm — Feature Engineering
#
# Exercises the sklearn pipeline from `src/features.py`.

# %%
import sys; sys.path.append('../src')
import pandas as pd
from features import build_feature_pipeline
df = pd.read_csv('../data/processed/tracks.csv')
y = df.pop('is_hit')
pipe = build_feature_pipeline().fit(df, y)
X = pipe.transform(df)
X.shape

# %%
pipe.named_steps['pre'].get_feature_names_out()[:25]
